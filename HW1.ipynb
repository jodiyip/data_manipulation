# %% [markdown]
# # SI 330 - Homework #1: Data Manipulation

# %% [markdown]
# ## Background

# %% [markdown]
# This homework assignment focuses on the analysis of historical data from the Olympic games.  The description of the data includes the following:
# > This is a historical dataset on the modern Olympic Games, including all the Games from Athens 1896 to Rio 2016. I scraped this data from www.sports-reference.com in May 2018.

# %% [markdown]
# Your main task in this assignment is to explore the data *using the data
# manipulation methods we covered in class* as well as those in the assigned readings.  You may need to consult pandas documentation, Stack Overflow, or other online resources.
#
# ** You should also feel free to ask questions on the [class Slack homework channel] (https://si330wn2019.slack.com/messages/CFA5AJPCL/)! **

# %% [markdown]
# A total of 50 points is available in this homework assignment, consisting of:
# - 40 points for completing the specific homework questions. More comprehensive
# answers will tend to gain more points.
# - 5 points for the overall quality of spelling, grammar, punctuation, and style of written responses.  (see https://faculty.washington.edu/heagerty/Courses/b572/public/StrunkWhite.pdf for a detailed specifications).
# - 5 points for creating code that conforms to [PEP 8](https://www.python.org/dev/peps/pep-0008/) guidelines.  You should review those guidelines before proceding with the assignment.

# %% [markdown]
# ## Answer the questions below.
# For each question, you should
# 1. Write code using Python and pandas that can help you answer the following questions, and
# 2. Explain your answers in plain English. You should use complete sentences that would be understood by an educated professional who is not necessarily a data scientist (like a product manager).

# %% [markdown]
# ### <font color="magenta"> Q1 (6 points): Explore and Describe the dataset.
# - How many rows and columns are there in the data frame? Please use the appropriate dataframe property.
# - Provide summary statistics (i.e. use the .describe() function) for age, height, and weight. Please present this information in a single dataframe.

# %%
import pandas as pd
import numpy as np
from math import *

# %%
# read and open athlete_events.csv
olympics = pd.read_csv('data/athlete_events.csv')
# finds dimensions of data file
olympics.shape

# %% [markdown]
# There are 15 columns and 271116 rows.

# %%
o1 = olympics[['Age', 'Height', 'Weight']].copy()

# %%
o1.describe()
# Out:
#                  Age         Height         Weight
# count  261642.000000  210945.000000  208241.000000
# mean       25.556898     175.338970      70.702393
# std         6.393561      10.518462      14.348020
# min        10.000000     127.000000      25.000000
# 25%        21.000000     168.000000      60.000000
# 50%        24.000000     175.000000      70.000000
# 75%        28.000000     183.000000      79.000000
# max        97.000000     226.000000     214.000000

# %% [markdown]
# I used the describe() function to find the summary statistic for age, height and weight.
# There are 261642 entries for age. The mean age is 25.5. The min is 10.0 and the max is 97.0.
# There are 210945 entries for height. The mean height is 175.3. The min is 127.0 and the max is 226.0.
# There are 208241 entries for weight. The mean weight is 70.7. The min is 25.0 and the max is 214.0.

# %% [markdown]
# ### <font color="magenta"> Q2 (8 points): How many unique athletes are in the dataset? What proportion of unique athletes are female?
#     - Ideally, your code should return a proportion without hardcoding.

# %%
number = olympics.Name
number.nunique()
# Out:
# 134732

# %% [markdown]
# There are 134732 unique athletes in the dataset.

# %%
olympics[olympics.Sex=='F']
# Out:
#             ID                                      Name Sex   Age  Height  \
# 4            5                  Christine Jacoba Aaftink   F  21.0   185.0
# 5            5                  Christine Jacoba Aaftink   F  21.0   185.0
# 6            5                  Christine Jacoba Aaftink   F  25.0   185.0
# 7            5                  Christine Jacoba Aaftink   F  25.0   185.0
# 8            5                  Christine Jacoba Aaftink   F  27.0   185.0
# 9            5                  Christine Jacoba Aaftink   F  27.0   185.0
# 26           8        Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.
kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 271054    62.0    Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 271055    62.0    Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 271057    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271058    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271059    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271060    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271061    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271062    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271063    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271064    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271065    53.0       Belarus  BLR  2002 Winter  2002  Winter  Salt Lake City
# 271076    80.0  Soviet Union  URS  1952 Summer  1952  Summer        Helsinki
# 271077    80.0  Soviet Union  URS  1952 Summer  1952  Summer        Helsinki
# 271078    80.0  Soviet Union  URS  1956 Summer  1956  Summer       Melbourne
# 271079    80.0  Soviet Union  URS  1960 Summer  1960  Summer            Roma
# 271080    80.0  Soviet Union  URS  1964 Summer  1964  Summer           Tokyo
# 271099    63.0        Greece  GRE  2004 Summer  2004  Summer          Athina
# 271102    64.0        Russia  RUS  2000 Summer  2000  Summer          Sydney
# 271103    64.0        Russia  RUS  2004 Summer  2004  Summer          Athina
# 271110    69.0       Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#                        Sport  \
# 4              Speed Skating
# 5              Speed Skating
# 6              Speed Skating
# 7              Speed Skating
# 8              Speed Skating
# 9              Speed Skating
# 26                 Athletics
# 27                 Athletics
# 32                   Sailing
# 33                   Sailing
# 34                  Biathlon
# 79                  Handball
# 80             Weightlifting
# 87                      Luge
# 91                    Hockey
# 105                 Football
# 135                Athletics
# 136                Athletics
# 161                Taekwondo
# 163                Athletics
# 164                Athletics
# 167               Basketball
# 176                   Rowing
# 193                Athletics
# 195                  Cycling
# 196                  Cycling
# 202                Athletics
# 252            Alpine Skiing
# 256                   Rowing
# 259            Weightlifting
# ...                      ...
# 271008                Hockey
# 271009                Hockey
# 271027             Athletics
# 271029             Athletics
# 271032                  Judo
# 271033                  Judo
# 271050         Speed Skating
# 271051         Speed Skating
# 271052             Athletics
# 271053             Athletics
# 271054             Athletics
# 271055             Athletics
# 271057  Cross Country Skiing
# 271058  Cross Country Skiing
# 271059  Cross Country Skiing
# 271060  Cross Country Skiing
# 271061  Cross Country Skiing
# 271062  Cross Country Skiing
# 271063  Cross Country Skiing
# 271064  Cross Country Skiing
# 271065  Cross Country Skiing
# 271076             Athletics
# 271077             Athletics
# 271078             Athletics
# 271079             Athletics
# 271080             Athletics
# 271099             Wrestling
# 271102             Athletics
# 271103             Athletics
# 271110            Basketball
#
#                                                     Event   Medal
# 4                        Speed Skating Women's 500 metres     NaN
# 5                      Speed Skating Women's 1,000 metres     NaN
# 6                        Speed Skating Women's 500 metres     NaN
# 7                      Speed Skating Women's 1,000 metres     NaN
# 8                        Speed Skating Women's 500 metres     NaN
# 9                      Speed Skating Women's 1,000 metres     NaN
# 26                           Athletics Women's 100 metres     NaN
# 27                 Athletics Women's 4 x 100 metres Relay     NaN
# 32                             Sailing Women's Windsurfer     NaN
# 33                             Sailing Women's Windsurfer     NaN
# 34                 Biathlon Women's 7.5 kilometres Sprint     NaN
# 79                              Handball Women's Handball    Gold
# 80                Weightlifting Women's Super-Heavyweight     NaN
# 87                                   Luge Women's Singles     NaN
# 91                                  Hockey Women's Hockey  Bronze
# 105                             Football Women's Football  Bronze
# 135                       Athletics Women's Javelin Throw     NaN
# 136                       Athletics Women's Javelin Throw     NaN
# 161                           Taekwondo Women's Flyweight  Bronze
# 163                       Athletics Women's Javelin Throw  Silver
# 164                       Athletics Women's Javelin Throw     NaN
# 167                         Basketball Women's Basketball     NaN
# 176                          Rowing Women's Coxless Pairs     NaN
# 193                            Athletics Women's Shot Put     NaN
# 195                                Cycling Women's Sprint  Silver
# 196                 Cycling Women's 500 metres Time Trial     NaN
# 202                            Athletics Women's Marathon     NaN
# 252                          Alpine Skiing Women's Slalom     NaN
# 256                          Rowing Women's Single Sculls     NaN
# 259                   Weightlifting Women's Featherweight     NaN
# ...                                                   ...     ...
# 271008                              Hockey Women's Hockey     NaN
# 271009                              Hockey Women's Hockey    Gold
# 271027                       Athletics Women's 800 metres     NaN
# 271029                        Athletics Women's High Jump     NaN
# 271032                          Judo Women's Middleweight  Bronze
# 271033                      Judo Women's Half-Heavyweight     NaN
# 271050                   Speed Skating Women's 500 metres     NaN
# 271051                 Speed Skating Women's 1,000 metres     NaN
# 271052                       Athletics Women's 200 metres     NaN
# 271053                       Athletics Women's 100 metres     NaN
# 271054                       Athletics Women's 200 metres     NaN
# 271055             Athletics Women's 4 x 100 metres Relay     NaN
# 271057         Cross Country Skiing Women's 10 kilometres     NaN
# 271058         Cross Country Skiing Women's 15 kilometres     NaN
# 271059         Cross Country Skiing Women's 30 kilometres     NaN
# 271060  Cross Country Skiing Women's 5/5 kilometres Pu...     NaN
# 271061  Cross Country Skiing Women's 4 x 5 kilometres ...     NaN
# 271062         Cross Country Skiing Women's 10 kilometres     NaN
# 271063         Cross Country Skiing Women's 15 kilometres     NaN
# 271064  Cross Country Skiing Women's 5/5 kilometres Pu...     NaN
# 271065  Cross Country Skiing Women's 4 x 5 kilometres ...     NaN
# 271076                         Athletics Women's Shot Put    Gold
# 271077                    Athletics Women's Javelin Throw     NaN
# 271078                         Athletics Women's Shot Put  Silver
# 271079                         Athletics Women's Shot Put     NaN
# 271080                         Athletics Women's Shot Put  Bronze
# 271099          Wrestling Women's Middleweight, Freestyle     NaN
# 271102             Athletics Women's 4 x 400 metres Relay  Bronze
# 271103             Athletics Women's 4 x 400 metres Relay  Silver
# 271110                      Basketball Women's Basketball     NaN
#
# [74522 rows x 15 columns]

# %%
sex = olympics.groupby('Sex').size()
sex
# Out:
# Sex
# F     74522
# M    196594
# dtype: int64

# %% [markdown]
# (Use this space to explain your answers)

# %%
sex.loc['F']/(sex.loc['F']+sex.loc['M'])
# Out:
# 0.2748712728131132

# %% [markdown]
# Around 0.275 of the unique athletes are females.

# %% [markdown]
# ### <font color="magenta"> Q3 (10 points): Looking at the time period from 1950 to today, which athelete competed in the most number of events?
# In which unique events did the athelete participate, and for what range of years? Which country did the athlete represent?

# %%
# filters athletes who participated from 1950 to today
athlete = olympics[olympics.Year>=1950].copy()
athlete.head()
# Out:
#    ID                      Name Sex   Age  Height  We
# 177438                    Gymnastics Men's Rings
# 177439          Gymnastics Men's Pommelled Horse
# Name: Event, dtype: object

# %% [markdown]
# See above for list of events Takashi Ono participated in

# %%
# Finds the last year Takashi Ono participated in the olympics
most.loc[most['Year'].idxmax()]
# Out:
# ID                                         89187
# Name                                 Takashi Ono
# Sex                                            M
# Age                                           33
# Height                                       160
# Weight                                        58
# Team                                       Japan
# NOC                                          JPN
# Games                                1964 Summer
# Year                                        1964
# Season                                    Summer
# City                                       Tokyo
# Sport                                 Gymnastics
# Event     Gymnastics Men's Individual All-Around
# Medal                                        NaN
# Name: 177432, dtype: object

# %% [markdown]
# The last year Takashi Ono participated in the Olympics was 1964.

# %%
# Finds the first year Takashi Ono participated in the olympics
most.loc[most['Year'].idxmin()]
# Out:
# ID                                         89187
# Name                                 Takashi Ono
# Sex                                            M
# Age                                           20
# Height                                       160
# Weight                                        58
# Team                                       Japan
# NOC                                          JPN
# Games                                1952 Summer
# Year                                        1952
# Season                                    Summer
# City                                    Helsinki
# Sport                                 Gymnastics
# Event     Gymnastics Men's Individual All-Around
# Medal                                        NaN
# Name: 177408, dtype: object

# %% [markdown]
# The first year Takashi Ono participated in the Olympics was 1952.

# %% [markdown]
# Takashi Ono from Japan competed from 1952 to 1964.

# %% [markdown]
# ### <font color="magenta"> Q4 (7 points): Which sport has the lowest median athlete age? Is there a tie?

# %%
# makes copy of dataframe sorting by age and sport
o2 = olympics[['Age', 'Sport']].copy()
o2.head()
# Out:
#     Age          Sport
# 0  24.0     Basketball
# 1  23.0           Judo
# 2  24.0       Football
# 3  34.0     Tug-Of-War
# 4  21.0  Speed Skating

# %%
# finds the median age for each sport and lists them in ascending order
o2.groupby('Sport').median().sort_values(by='Age', ascending = True).head()
# Out:
#                         Age
# Sport
# Rhythmic Gymnastics    18.0
# Swimming               20.0
# Synchronized Swimming  22.0
# Figure Skating         22.0
# Diving                 22.0

# %% [markdown]
# Rhythmic gymnastic has the lowest median age of 18.0. There is no tie.

# %% [markdown]
# ### <font color="magenta"> Q5 (8 points): In which year did Canada win the most medals?

# %%
# filters only data with Canada
o3 = olympics[olympics.Team=='Canada']
o3.head()
# Out:
#       ID                       Name Sex   Age  Height  Weight    Team  NOC  \
# 269  140  William "Bill" Abbott Jr.   M  42.0   172.0    80.0  Canada  CAN
# 270  140  William "Bill" Abbott Jr.   M  46.0   172.0    80.0  Canada  CAN
# 279  146              Jeremy Abbott   M  19.0   179.0    71.0  Canada  CAN
# 280  147              Joanne Abbott   F  41.0   160.0    57.0  Canada  CAN
# 281  148     Kathryn "Katie" Abbott   F  21.0   164.0    63.0  Canada  CAN
#
#            Games  Year  Season      City     Sport  \
# 269  1996 Summer  1996  Summer   Atlanta   Sailing
# 270  2000 Summer  2000  Summer    Sydney   Sailing
# 279  1976 Summer  1976  Summer  Montreal  Canoeing
# 280  1996 Summer  1996  Summer   Atlanta   Sailing
# 281  2008 Summer  2008  Summer   Beijing   Sailing
#
#                                              Event Medal
# 269            Sailing Mixed Three Person Keelboat   NaN
# 270            Sailing Mixed Three Person Keelboat   NaN
# 279  Canoeing Men's Canadian Doubles, 1,000 metres   NaN
# 280            Sailing Mixed Three Person Keelboat   NaN
# 281          Sailing Women's Three Person Keelboat   NaN

# %%
# sorts by data by year and medal
new_o3 = o3[['Year', 'Medal']].sort_values(by='Year', ascending=True).copy()
new_o3.head()
# Out:
#         Year   Medal
# 83481   1900     NaN
# 178304  1900  Bronze
# 178306  1900     NaN
# 83480   1900     NaN
# 83497   1900     NaN

# %%
# finds the year with the most medal counts by sorting by descending order
new_o3.groupby('Year').count().sort_values(by='Medal', ascending=False).head(1)
# Out:
#       Medal
# Year
# 1984     91

# %% [markdown]
# Canada won the most medals in 1981. Canada won 91 medals.

# %% [markdown]
# ### <font color="magenta"> Q6 (11 points): In which sports in the 2014 Winter Olympics did female medalists win more medal points than male medalists?

# %%
o6 = olympics.copy()
# filters data in only the 2014 olympics
winter = o6[o6.Year==2014]
# sets and counts point values for medals
medal = winter[(winter.Medal=='Gold') |(winter.Medal=='Silver') | (winter.Medal=='Bronze')]
for i in medal['Medal']:
    if i == 'Gold':
        medal['Points'] = 3
    elif i == 'Silver':
        medal['Points'] = 2
    else:
        i == 'Bronze'
        medal['Points'] = 1
# Out:
# C:\Users\jodiy\Anaconda3.1\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\jodiy\Anaconda3.1\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\jodiy\Anaconda3.1\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# separates data by sex
male = medal[medal.Sex=='M']
female = medal[medal.Sex=='F']

# %%
# finds points for male medalists for each sport
male.groupby('Sport').Points.sum()
# Out:
# Sport
# Alpine Skiing                 48
# Biathlon                      90
# Bobsleigh                     54
# Cross Country Skiing          90
# Curling                       36
# Figure Skating                69
# Freestyle Skiing              45
# Ice Hockey                   213
# Luge                          54
# Nordic Combined               54
# Short Track Speed Skating     63
# Skeleton                       9
# Ski Jumping                   54
# Snowboarding                  45
# Speed Skating                 72
# Name: Points, dtype: int64

# %%
# finds points for female medalists for each sport
female.groupby('Sport').Points.sum()
# Out:
# Sport
# Alpine Skiing                 45
# Biathlon                      90
# Bobsleigh                     18
# Cross Country Skiing          90
# Curling                       36
# Figure Skating                66
# Freestyle Skiing              45
# Ice Hockey                   177
# Luge                          18
# Short Track Speed Skating     66
# Skeleton                       9
# Ski Jumping                    9
# Snowboarding                  45
# Speed Skating                 81
# Name: Points, dtype: int64

# %% [markdown]
# In the 2014 winter olympics, female medalists won more points than male medalists in short track speed skating (66 vs 63) and in speed skating (81 vs 72).

# %% [markdown]
# ### QBonus 5 pt: For each year in which games were held, what proportion of the host country medalists were women?
# You will need to combine multiple datasets to complete the analysis.
# <p>Suggested data:
# <p>- https://en.wikipedia.org/wiki/List_of_Olympic_Games_host_cities (note: we suggest you use pd.read_html)

# %%
# put your code here

# %% [markdown]
# (Use this space to explain your answers)

# %% [markdown]
# ## Please submit your completed notebook in .IPYNB and .HTML formats via Canvas
